# %% [markdown]
# # Bayesian optimization of a time-consuming simulator
#
# O. Roustant, INSA Toulouse
#
# The aim of the lab is to optimize a time-consuming simulator using the Efficient Global Optimization (EGO) method. As a toy example, the simulator chosen here mimics a catapult. There are 4 input variables, tuning the catapult, and 1 output, giving the distance of the projectile mark to the catapult. We want to find the value(s) of the input variable(s) maximizing that distance. Notice that the simulator is not time-consuming. However, for the sake of realism, we will limit the computational budget to 36 runs.

# %% [markdown]
# ## "By-hand" Optimization
# <br> We provide here a shiny application created by Nicolas Durrande, which allows using the simulator interactively. Alternatively, you can use the web application, available here : https://durrande.shinyapps.io/catapult/

# %%
library(shiny)
# runApp()

# %% [markdown]
# *Question: By playing with the simulator, propose a set of input values giving the largest possible value of the output. Here we consider the noise-free case, by fixing the wind to zero.*

# %% [markdown]
# To continue running the notebook, you may need to interrupt the kernel (square symbol!). Then load the two following scripts, containing useful functions.

# %%
source("catapultSettings.R")
source("catapultFunctions.R")

# %% [markdown]
# ## Design of experiments
# Let us create an initial design of experiments and compute the corresponding values.

# %%
library(DiceDesign)
set.seed(0)
ninit <- 16
d <- 4
X0 <- lhsDesign(n = ninit, dimension = d)$design
Xopt <- maximinESE_LHS(X0, it = 10)
## you may be interested in the convergence
#plot(Xopt$critValues,type="l")
X <- Xopt$design
colnames(X) <- c("axis", "arm", "spring1", "spring2")
pairs(X)
## compute the output values
Y <- apply(X, 1, runExperiment, windFactor = 0)[1, ]
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title

# %% [markdown]
# Question : Observe that the design of experiments is "space-filling". <br> Why did we chose that kind of designs? What is the current maximum? Is it far from the maximum value found by-hand?

# %%
max(Y)
# Out:
# [1] 162.4945

# %% [markdown]
# ## Descriptive statistics
# *Question : Can you see a simple input-output relation? What can you say about the area corresponding to the maximum value?*

# %%
pairs(cbind(Y, X))
# Out:
# plot without title

# %% [markdown]
# ## Regression metamodel
# <br> *Question : Try the linear models below. If you replace the simulator by one of this model, what would be the optimum? Is it far from your previous guess?*

# %%
myData <- data.frame(X, Y = Y)
mReg <- lm(Y ~ ., data = myData)
summary(mReg)
runExperiment(c(0, 1, 1, 1), windFactor = 0)[1]
mReg2 <- lm(Y~ . + I(axis^2) + I (arm^2) + I (spring1^2) + I(spring2^2), data = myData)
summary(mReg2)
mStep <- step(object = mReg, scope = mReg2, direction = "both", k = log(length(Y)))
summary(mStep)
# Out:
# Call:
# lm(formula = Y ~ ., data = myData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -40.334  -4.769   0.080   7.366  20.316
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)    64.82      18.39   3.525 0.004753 **
# axis          -81.32      15.27  -5.327 0.000242 ***
# arm           119.42      15.83   7.545 1.13e-05 ***
# spring1       -19.33      15.17  -1.275 0.228684
# spring2        21.06      14.96   1.408 0.186732
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 17.12 on 11 degrees of freedom
# Multiple R-squared:  0.9059,	Adjusted R-squared:  0.8717
# F-statistic: 26.47 on 4 and 11 DF,  p-value: 1.355e-05
# [1] 86.3381
# Call:
# lm(formula = Y ~ . + I(axis^2) + I(arm^2) + I(spring1^2) + I(spring2^2),
#     data = myData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -24.501  -9.365   1.033   9.651  20.065
#
# Coefficients:
#              Estimate Std. Error t value Pr(>|t|)
# (Intercept)     52.66      39.09   1.347   0.2199
# axis           -67.84      76.00  -0.893   0.4017
# arm            211.92      72.78   2.912   0.0226 *
# spring1        -39.34      75.05  -0.524   0.6163
# spring2        -10.52      66.44  -0.158   0.8787
# I(axis^2)      -14.19      70.44  -0.201   0.8461
# I(arm^2)       -91.00      68.90  -1.321   0.2281
# I(spring1^2)    19.51      70.66   0.276   0.7904
# I(spring2^2)    39.52      64.69   0.611   0.5606
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 18.5 on 7 degrees of freedom
# Multiple R-squared:  0.9301,	Adjusted R-squared:  0.8501
# F-statistic: 11.64 on 8 and 7 DF,  p-value: 0.002051
# Start:  AIC=98.76
# Y ~ axis + arm + spring1 + spring2
#
#           Df Sum of Sq     RSS     AIC
# - spring1  1     476.4  3701.8  98.194
# - spring2  1     581.4  3806.7  98.641
# <none>                  3225.3  98.762
# - axis     1    8321.4 11546.8 116.395
# - arm      1   16692.1 19917.4 125.119
#
# Step:  AIC=98.19
# Y ~ axis + arm + spring2
#
#           Df Sum of Sq     RSS     AIC
# - spring2  1     651.1  4352.9  98.014
# <none>                  3701.8  98.194
# - axis     1    7982.0 11683.8 113.812
# - arm      1   19045.1 22746.8 124.471
#
# Step:  AIC=98.01
# Y ~ axis + arm
#
#        Df Sum of Sq     RSS     AIC
# <none>               4352.9  98.014
# - axis  1      7924 12276.9 111.831
# - arm   1     18439 22792.2 121.731
# Call:
# lm(formula = Y ~ axis + arm, data = myData)
#
# Residuals:
#     Min      1Q  Median      3Q     Max
# -48.113  -7.451   2.187  10.176  30.496
#
# Coefficients:
#             Estimate Std. Error t value Pr(>|t|)
# (Intercept)    63.38      13.05   4.858 0.000313 ***
# axis          -78.85      16.21  -4.865 0.000309 ***
# arm           120.96      16.30   7.421 5.04e-06 ***
# ---
# Signif. codes:  0 ‘***’ 0.001 ‘**’ 0.01 ‘*’ 0.05 ‘.’ 0.1 ‘ ’ 1
#
# Residual standard error: 18.3 on 13 degrees of freedom
# Multiple R-squared:  0.873,	Adjusted R-squared:  0.8534
# F-statistic: 44.68 on 2 and 13 DF,  p-value: 1.496e-06
# plot without title

# %% [markdown]
# ## Bayesian optimization
# Now, let us try the EGO method (Bayesian optimization)
# <br> *Question : Recall its main principles.*

# %%
library(DiceKriging)
mGP0 <- km(~ 1, design = X, response = Y, multistart = 5)
print(mGP0)   # display model
plot(mGP0)    # visual model validation
# Out:
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -73.48833 -75.88534 -77.37101 -77.58722 -79.20687
# Warning message:
# “executing %dopar% sequentially: no parallel backend registered”
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       73.488  |proj g|=        1.145
# At iterate     1  f =       72.773  |proj g|=        1.0374
# At iterate     2  f =       71.944  |proj g|=       0.72097
# At iterate     3  f =        71.84  |proj g|=       0.90383
# At iterate     4  f =       71.703  |proj g|=        1.3708
# At iterate     5  f =       71.616  |proj g|=         1.062
# At iterate     6  f =         71.6  |proj g|=       0.13378
# At iterate     7  f =       71.591  |proj g|=       0.26421
# At iterate     8  f =       71.569  |proj g|=       0.52642
# At iterate     9  f =       71.564  |proj g|=       0.44332
# At iterate    10  f =       71.562  |proj g|=      0.021479
# At iterate    11  f =       71.562  |proj g|=      0.013962
# At iterate    12  f =       71.562  |proj g|=     0.0024829
# At iterate    13  f =       71.562  |proj g|=    9.4506e-07
#
# iterations 13
# function evaluations 16
# segments explored during Cauchy searches 16
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 9.45063e-07
# final function value 71.5622
#
# F = 71.5622
# final  value 71.562205
# converged
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       75.885  |proj g|=       1.4296
# At iterate     1  f =        74.44  |proj g|=        1.1252
# At iterate     2  f =       72.947  |proj g|=       0.94067
# At iterate     3  f =       72.345  |proj g|=        1.4368
# At iterate     4  f =        72.01  |proj g|=        1.1943
# At iterate     5  f =       71.785  |proj g|=        1.1443
# At iterate     6  f =        71.59  |proj g|=       0.52736
# At iterate     7  f =       71.566  |proj g|=       0.29081
# At iterate     8  f =       71.563  |proj g|=       0.13477
# At iterate     9  f =       71.562  |proj g|=     0.0060997
# At iterate    10  f =       71.562  |proj g|=     0.0002446
# At iterate    11  f =       71.562  |proj g|=    8.2028e-06
#
# iterations 11
# function evaluations 13
# segments explored during Cauchy searches 15
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 8.20284e-06
# final function value 71.5622
#
# F = 71.5622
# final  value 71.562205
# converged
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       77.371  |proj g|=       1.6435
# At iterate     1  f =       72.927  |proj g|=        1.4673
# At iterate     2  f =       72.306  |proj g|=        1.1497
# At iterate     3  f =        72.14  |proj g|=       0.70608
# At iterate     4  f =       71.857  |proj g|=        0.5532
# At iterate     5  f =       71.676  |proj g|=       0.75312
# At iterate     6  f =       71.583  |proj g|=       0.64806
# At iterate     7  f =       71.563  |proj g|=       0.20481
# At iterate     8  f =       71.562  |proj g|=      0.064673
# At iterate     9  f =       71.562  |proj g|=     0.0008302
# At iterate    10  f =       71.562  |proj g|=    3.1985e-06
#
# iterations 10
# function evaluations 12
# segments explored during Cauchy searches 13
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 3.19848e-06
# final function value 71.5622
#
# F = 71.5622
# final  value 71.562205
# converged
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       77.587  |proj g|=       1.4829
# At iterate     1  f =       75.091  |proj g|=        0.9537
# At iterate     2  f =       73.788  |proj g|=       0.76565
# At iterate     3  f =       72.515  |proj g|=        1.3829
# At iterate     4  f =       72.225  |proj g|=        1.1741
# At iterate     5  f =       71.589  |proj g|=       0.52087
# At iterate     6  f =       71.564  |proj g|=       0.13199
# At iterate     7  f =       71.562  |proj g|=      0.077398
# At iterate     8  f =       71.562  |proj g|=     0.0026844
# At iterate     9  f =       71.562  |proj g|=     0.0012639
# At iterate    10  f =       71.562  |proj g|=    0.00016919
#
# iterations 10
# function evaluations 13
# segments explored during Cauchy searches 14
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0.000169192
# final function value 71.5622
#
# F = 71.5622
# final  value 71.562205
# converged
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       79.207  |proj g|=       1.6322
# At iterate     1  f =       72.953  |proj g|=        1.1903
# At iterate     2  f =       72.588  |proj g|=        1.4155
# At iterate     3  f =       72.338  |proj g|=        1.3853
# At iterate     4  f =        71.81  |proj g|=       0.97027
# At iterate     5  f =       71.657  |proj g|=       0.95753
# At iterate     6  f =       71.564  |proj g|=       0.36707
# At iterate     7  f =       71.562  |proj g|=      0.087917
# At iterate     8  f =       71.562  |proj g|=     0.0074353
# At iterate     9  f =       71.562  |proj g|=    0.00099315
# At iterate    10  f =       71.562  |proj g|=    2.3858e-05
#
# iterations 10
# function evaluations 12
# segments explored during Cauchy searches 13
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 2.38581e-05
# final function value 71.5622
#
# F = 71.5622
# final  value 71.562205
# converged
#
# * The 5 best values (multistart) obtained are:
#  71.5622 71.5622 71.5622 71.5622 71.5622
# * The model corresponding to the best one (71.5622) is stored.
#
# Call:
# km(formula = ~1, design = X, response = Y, multistart = 5)
#
# Trend  coeff.:
#                Estimate
#  (Intercept)    76.9026
#
# Covar. type  : matern5_2
# Covar. coeff.:
#                  Estimate
#    theta(axis)     0.8533
#     theta(arm)     0.5108
# theta(spring1)     1.9339
# theta(spring2)     1.9149
#
# Variance estimate: 2149.272
# Plot with title “Normal QQ-plot of standardized residuals”

# %% [markdown]
# *Questions: What is the role of the argument 'multistart'? What can you say about the performance and the validity of this first model?*

# %%
library(DiceOptim)

## We first transform the problem to a minimization one
runExperimentFun <- function(x) {
    - runExperiment(x, wind = 0)[1]
}
Y <- apply(X, 1, runExperimentFun)
mGP0 <- km(~ 1, design = X, response = Y)

## Step 1 ##
oEGO <- max_EI(model = mGP0, lower = rep(0, d), upper = rep(1, d))
newX <- oEGO$par
newy <- runExperimentFun(newX)

cat("Expected improvement was:", round(oEGO$value, 2),
    "\nActual improvement is:", round(min(Y) - newy, 2),
    "\n   (>0 means the new point is better, <0 means it is worse)")
# Out:
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -74.91098
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       74.911  |proj g|=        1.502
# At iterate     1  f =       73.706  |proj g|=        1.2168
# At iterate     2  f =       73.001  |proj g|=        1.1328
# At iterate     3  f =       72.367  |proj g|=        1.4181
# At iterate     4  f =       72.056  |proj g|=        1.3827
# At iterate     5  f =       71.648  |proj g|=       0.37015
# At iterate     6  f =       71.563  |proj g|=       0.11779
# At iterate     7  f =       71.562  |proj g|=      0.054386
# At iterate     8  f =       71.562  |proj g|=      0.013987
# At iterate     9  f =       71.562  |proj g|=     0.0075976
# At iterate    10  f =       71.562  |proj g|=    6.7409e-06
# At iterate    11  f =       71.562  |proj g|=    3.4984e-08
#
# iterations 11
# function evaluations 13
# segments explored during Cauchy searches 14
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 3.49838e-08
# final function value 71.5622
#
# F = 71.5622
# final  value 71.562205
# converged
#
#
# Thu Sep 16 13:44:17 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	3.437813e+00
#       1 	7.986047e+00
#       2 	8.627129e+00
#       3 	1.328577e+01
#       4 	1.328577e+01
#       5 	1.328577e+01
#       6 	1.328577e+01
#       7 	1.328577e+01
#       8 	1.328577e+01
#       9 	1.328577e+01
#      10 	1.328577e+01
#      11 	1.328577e+01
#      12 	1.328577e+01
# Warning message in genoud(EI, nvars = d, max = TRUE, pop.size = control$pop.size, :
# “Stopped because hard maximum generation limit was hit.”
# NOTE: HARD MAXIMUM GENERATION LIMIT HIT
#
# Solution Fitness Value: 1.328577e+01
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	1.616548e-01	G[ 1] :	2.747356e-06
#  X[ 2] :	8.045908e-01	G[ 2] :	-1.359096e-06
#  X[ 3] :	0.000000e+00	G[ 3] :	-4.131892e+00
#  X[ 4] :	1.000000e+00	G[ 4] :	1.887406e+01
#
# Solution Found Generation 12
# Number of Generations Run 12
#
# Thu Sep 16 13:44:17 2021
# Total run time : 0 hours 0 minutes and 0 seconds
# plot without title
# Expected improvement was: 13.29
# Actual improvement is: 8.75
#    (>0 means the new point is better, <0 means it is worse)
# plot without title

# %%
# Then we update the model
mGP1 <- update(mGP0, newX, newy)
# and maximize again the expected improvement: 
## Step 2 ##
oEGO <- max_EI(model = mGP1, lower = rep(0, d), upper = rep(1, d))
newX <- oEGO$par
newy <- runExperimentFun(newX)

cat("Expected improvement was:", round(oEGO$value, 2),
    "\nActual improvement is:", round(min(mGP1@y) - newy, 2),
    "\n   (>0 means the new point is better, <0 means its worst)")
# Out:
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -79.91007
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=        79.91  |proj g|=       1.1906
# At iterate     1  f =       77.738  |proj g|=        1.0072
# At iterate     2  f =       76.249  |proj g|=        1.3779
# At iterate     3  f =       75.767  |proj g|=        1.3911
# At iterate     4  f =        75.38  |proj g|=       0.54625
# At iterate     5  f =       75.169  |proj g|=       0.39556
# At iterate     6  f =       75.027  |proj g|=        1.3624
# At iterate     7  f =       74.919  |proj g|=         1.103
# At iterate     8  f =       74.912  |proj g|=       0.55593
# At iterate     9  f =       74.908  |proj g|=       0.19702
# At iterate    10  f =       74.908  |proj g|=     0.0040895
# At iterate    11  f =       74.908  |proj g|=    8.7938e-05
# At iterate    12  f =       74.908  |proj g|=    9.0057e-09
#
# iterations 12
# function evaluations 16
# segments explored during Cauchy searches 15
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 9.00569e-09
# final function value 74.9079
#
# F = 74.9079
# final  value 74.907898
# converged
#
#
# Thu Sep 16 13:45:22 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	6.996478e-02
#       1 	9.540303e-01
#       2 	9.643668e-01
#       3 	1.475441e+00
#       4 	1.475441e+00
#       5 	1.475441e+00
#       7 	1.475441e+00
#       8 	1.475441e+00
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 1.475441e+00
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	2.897191e-01	G[ 1] :	-4.594806e-07
#  X[ 2] :	8.299259e-01	G[ 2] :	-8.787027e-08
#  X[ 3] :	1.822203e-01	G[ 3] :	1.053170e-07
#  X[ 4] :	1.000000e+00	G[ 4] :	1.107437e+01
#
# Solution Found Generation 8
# Number of Generations Run 11
#
# Thu Sep 16 13:45:22 2021
# Total run time : 0 hours 0 minutes and 0 seconds
# Expected improvement was: 1.48
# Actual improvement is: 2.41
#    (>0 means the new point is better, <0 means its worst)
# plot without title

# %%
# Do a loop to automatize the process (for noise-free observations, you can also use EGO.nsteps)
nsteps <- 20
mGP <- mGP0
EGOpar <- matrix(NA, nrow = nsteps, ncol = d)
EGOvalue <- rep(NA, nsteps)
for (i in 1:nsteps){
    oEGO <- max_EI(model = mGP, lower = rep(0, d), upper = rep(1, d))
    newX <- EGOpar[i, ] <- oEGO$par
    newy <- EGOvalue[i] <- runExperimentFun(newX)
    mGP <- update(mGP, newX, newy)
}

bestIndex <- which.min(EGOvalue)
cat("longest shot observed:", - round(EGOvalue[bestIndex], 2),
    "\ncorresponding input values:", round(EGOpar[bestIndex, ], 2))
# Out:
# Thu Sep 16 13:45:41 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	5.351116e+00
#       1 	9.085007e+00
#       2 	1.116645e+01
#       3 	1.328577e+01
#       4 	1.328577e+01
#       5 	1.328577e+01
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 1.328577e+01
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	1.616548e-01	G[ 1] :	3.334621e-07
#  X[ 2] :	8.045908e-01	G[ 2] :	2.211095e-07
#  X[ 3] :	0.000000e+00	G[ 3] :	-4.131892e+00
#  X[ 4] :	1.000000e+00	G[ 4] :	1.887406e+01
#
# Solution Found Generation 5
# Number of Generations Run 8
#
# Thu Sep 16 13:45:41 2021
# Total run time : 0 hours 0 minutes and 0 seconds
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -76.44234
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       76.442  |proj g|=      0.70749
# At iterate     1  f =       76.059  |proj g|=       0.66308
# At iterate     2  f =       75.248  |proj g|=       0.52988
# At iterate     3  f =       75.114  |proj g|=          1.38
# At iterate     4  f =       75.046  |proj g|=        1.3652
# At iterate     5  f =       75.014  |proj g|=        0.4874
# At iterate     6  f =       74.976  |proj g|=       0.51079
# At iterate     7  f =       74.936  |proj g|=       0.52502
# At iterate     8  f =       74.911  |proj g|=       0.51599
# At iterate     9  f =       74.908  |proj g|=      0.011318
# At iterate    10  f =       74.908  |proj g|=     0.0084487
# At iterate    11  f =       74.908  |proj g|=     0.0022169
# At iterate    12  f =       74.908  |proj g|=    0.00020215
#
# iterations 12
# function evaluations 15
# segments explored during Cauchy searches 15
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0.000202153
# final function value 74.9079
#
# F = 74.9079
# final  value 74.907898
# converged
#
#
# Thu Sep 16 13:45:42 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	1.477528e-01
#       1 	6.058858e-01
#       2 	1.671882e+00
#       3 	2.606151e+00
#       4 	2.606151e+00
#       5 	2.606151e+00
#       6 	2.606151e+00
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 2.606151e+00
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	0.000000e+00	G[ 1] :	-9.599266e+00
#  X[ 2] :	7.182430e-01	G[ 2] :	-2.226859e-09
#  X[ 3] :	0.000000e+00	G[ 3] :	-3.818042e-01
#  X[ 4] :	1.000000e+00	G[ 4] :	3.385609e+00
#
# Solution Found Generation 6
# Number of Generations Run 9
#
# Thu Sep 16 13:45:42 2021
# Total run time : 0 hours 0 minutes and 0 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -81.62397
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       81.624  |proj g|=        1.186
# At iterate     1  f =       79.231  |proj g|=       0.67559
# At iterate     2  f =       78.783  |proj g|=        1.1463
# At iterate     3  f =       78.357  |proj g|=        1.1157
# At iterate     4  f =       78.174  |proj g|=       0.94465
# At iterate     5  f =       78.064  |proj g|=       0.67449
# At iterate     6  f =       78.041  |proj g|=       0.17515
# At iterate     7  f =        78.04  |proj g|=      0.015263
# At iterate     8  f =        78.04  |proj g|=    0.00026006
# At iterate     9  f =        78.04  |proj g|=     4.746e-07
#
# iterations 9
# function evaluations 14
# segments explored during Cauchy searches 13
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 4.746e-07
# final function value 78.0397
#
# F = 78.0397
# final  value 78.039655
# converged
#
#
# Thu Sep 16 13:45:42 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	4.570021e-03
#       1 	1.894636e-01
#       2 	2.670384e-01
#       3 	9.166892e-01
#       4 	9.166892e-01
#       6 	9.166892e-01
#       7 	9.166892e-01
#       8 	9.166892e-01
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 9.166892e-01
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	0.000000e+00	G[ 1] :	-7.248680e+00
#  X[ 2] :	7.878769e-01	G[ 2] :	2.906253e-07
#  X[ 3] :	0.000000e+00	G[ 3] :	-4.545334e-02
#  X[ 4] :	1.000000e+00	G[ 4] :	1.937097e+00
#
# Solution Found Generation 8
# Number of Generations Run 11
#
# Thu Sep 16 13:45:42 2021
# Total run time : 0 hours 0 minutes and 0 seconds
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -95.68765
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       95.688  |proj g|=       1.4305
# At iterate     1  f =       91.979  |proj g|=       0.82874
# At iterate     2  f =       90.319  |proj g|=       0.79116
# At iterate     3  f =       88.127  |proj g|=        0.7757
# At iterate     4  f =       87.543  |proj g|=        1.5241
# At iterate     5  f =       87.273  |proj g|=        1.3489
# At iterate     6  f =       86.986  |proj g|=        1.3495
# At iterate     7  f =       86.413  |proj g|=       0.57636
# At iterate     8  f =       86.404  |proj g|=        0.1553
# At iterate     9  f =       86.404  |proj g|=      0.073639
# At iterate    10  f =       86.404  |proj g|=      0.097476
# At iterate    11  f =       86.403  |proj g|=       0.21417
# At iterate    12  f =       86.403  |proj g|=        0.2149
# At iterate    13  f =       86.402  |proj g|=       0.19372
# At iterate    14  f =       86.402  |proj g|=      0.020533
# At iterate    15  f =       86.402  |proj g|=     0.0056782
# At iterate    16  f =       86.402  |proj g|=     0.0044972
# At iterate    17  f =       86.402  |proj g|=    8.1432e-05
#
# iterations 17
# function evaluations 21
# segments explored during Cauchy searches 21
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 8.14316e-05
# final function value 86.4021
#
# F = 86.4021
# final  value 86.402096
# converged
#
#
# Thu Sep 16 13:45:42 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	2.078599e+00
#       1 	1.235066e+01
#       2 	1.361918e+01
#       3 	1.529749e+01
#       4 	1.529749e+01
#       5 	1.529749e+01
#       6 	1.529749e+01
#       7 	1.529749e+01
#       8 	1.529749e+01
#       9 	1.529749e+01
#      10 	1.529749e+01
#      11 	1.529749e+01
#      12 	1.529749e+01
# Warning message in genoud(EI, nvars = d, max = TRUE, pop.size = control$pop.size, :
# “Stopped because hard maximum generation limit was hit.”
# plot without title
# NOTE: HARD MAXIMUM GENERATION LIMIT HIT
#
# Solution Fitness Value: 1.529749e+01
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	1.293734e-01	G[ 1] :	-7.342568e-05
#  X[ 2] :	6.665954e-01	G[ 2] :	1.738553e-04
#  X[ 3] :	1.326019e-01	G[ 3] :	2.064694e-04
#  X[ 4] :	1.000000e+00	G[ 4] :	2.868442e+01
#
# Solution Found Generation 12
# Number of Generations Run 12
#
# Thu Sep 16 13:45:43 2021
# Total run time : 0 hours 0 minutes and 1 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -93.42128
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       93.421  |proj g|=       0.7757
# At iterate     1  f =       92.331  |proj g|=       0.70084
# At iterate     2  f =       90.575  |proj g|=       0.42942
# At iterate     3  f =       90.504  |proj g|=        1.5632
# At iterate     4  f =       90.328  |proj g|=        1.5329
# At iterate     5  f =       90.229  |proj g|=         1.036
# At iterate     6  f =       89.779  |proj g|=        0.5959
# At iterate     7  f =       89.754  |proj g|=       0.41707
# At iterate     8  f =       89.746  |proj g|=       0.15971
# At iterate     9  f =       89.746  |proj g|=      0.038228
# At iterate    10  f =       89.746  |proj g|=       0.01961
# At iterate    11  f =       89.746  |proj g|=      0.016685
# At iterate    12  f =       89.746  |proj g|=      0.015664
# At iterate    13  f =       89.746  |proj g|=         0.028
# At iterate    14  f =       89.746  |proj g|=      0.020176
# At iterate    15  f =       89.746  |proj g|=      0.032215
# At iterate    16  f =       89.746  |proj g|=      0.025109
# At iterate    17  f =       89.746  |proj g|=    0.00022724
# At iterate    18  f =       89.746  |proj g|=    5.0103e-05
#
# iterations 18
# function evaluations 21
# segments explored during Cauchy searches 21
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 1
# norm of the final projected gradient 5.01026e-05
# final function value 89.7455
#
# F = 89.7455
# final  value 89.745536
# converged
#
#
# Thu Sep 16 13:45:43 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	1.130540e-01
#       1 	5.023463e-01
#       2 	7.854283e-01
#       3 	1.222572e+00
#       4 	1.222572e+00
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 1.222572e+00
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	0.000000e+00	G[ 1] :	-5.145508e+00
#  X[ 2] :	5.951509e-01	G[ 2] :	1.372378e-08
#  X[ 3] :	0.000000e+00	G[ 3] :	-4.212772e-01
#  X[ 4] :	1.000000e+00	G[ 4] :	2.942201e+00
#
# Solution Found Generation 4
# Number of Generations Run 7
#
# Thu Sep 16 13:45:43 2021
# Total run time : 0 hours 0 minutes and 0 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -102.7295
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       102.73  |proj g|=       1.6792
# At iterate     1  f =       97.353  |proj g|=        1.5161
# At iterate     2  f =       95.929  |proj g|=        1.4162
# At iterate     3  f =       94.401  |proj g|=        1.3995
# At iterate     4  f =       93.709  |proj g|=        1.2003
# At iterate     5  f =       93.631  |proj g|=       0.52382
# At iterate     6  f =        93.54  |proj g|=       0.72853
# At iterate     7  f =       93.485  |proj g|=       0.60695
# At iterate     8  f =       93.475  |proj g|=       0.39431
# At iterate     9  f =       93.474  |proj g|=      0.048808
# At iterate    10  f =       93.473  |proj g|=    0.00075118
# At iterate    11  f =       93.473  |proj g|=     4.166e-06
#
# iterations 11
# function evaluations 13
# segments explored during Cauchy searches 14
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 4.16601e-06
# final function value 93.4735
#
# F = 93.4735
# final  value 93.473498
# converged
#
#
# Thu Sep 16 13:45:43 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	9.020163e-02
#       1 	1.441881e-01
#       2 	3.216691e-01
#       3 	5.669605e-01
#       4 	5.669605e-01
#       5 	5.669605e-01
#       7 	5.669605e-01
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 5.669605e-01
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	3.956923e-01	G[ 1] :	-6.057468e-07
#  X[ 2] :	8.277482e-01	G[ 2] :	6.166496e-07
#  X[ 3] :	0.000000e+00	G[ 3] :	-1.079423e+00
#  X[ 4] :	1.000000e+00	G[ 4] :	4.557460e+00
#
# Solution Found Generation 7
# Number of Generations Run 10
#
# Thu Sep 16 13:45:43 2021
# Total run time : 0 hours 0 minutes and 0 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -100.9763
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       100.98  |proj g|=       1.4505
# At iterate     1  f =       99.209  |proj g|=       0.68733
# At iterate     2  f =       98.228  |proj g|=        1.5374
# At iterate     3  f =        98.01  |proj g|=       0.59878
# At iterate     4  f =       97.903  |proj g|=       0.58186
# At iterate     5  f =       97.407  |proj g|=        1.5273
# At iterate     6  f =       96.958  |proj g|=        1.5227
# At iterate     7  f =       96.673  |proj g|=       0.38797
# At iterate     8  f =       96.668  |proj g|=       0.14904
# At iterate     9  f =       96.667  |proj g|=      0.068476
# At iterate    10  f =       96.667  |proj g|=       0.18445
# At iterate    11  f =       96.666  |proj g|=      0.078972
# At iterate    12  f =       96.666  |proj g|=      0.018389
# At iterate    13  f =       96.666  |proj g|=     0.0091475
# At iterate    14  f =       96.666  |proj g|=    2.0182e-05
# At iterate    15  f =       96.666  |proj g|=    5.1115e-07
#
# iterations 15
# function evaluations 17
# segments explored during Cauchy searches 18
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 5.11155e-07
# final function value 96.6664
#
# F = 96.6664
# final  value 96.666350
# converged
#
#
# Thu Sep 16 13:45:44 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	2.820487e-03
#       1 	9.392014e-03
#       2 	1.924488e-02
#       3 	9.493900e-02
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 9.493900e-02
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	1.000000e+00	G[ 1] :	2.629729e-01
#  X[ 2] :	1.000000e+00	G[ 2] :	9.661084e-01
#  X[ 3] :	1.000000e+00	G[ 3] :	1.373484e-01
#  X[ 4] :	1.000000e+00	G[ 4] :	2.076902e-01
#
# Solution Found Generation 3
# Number of Generations Run 6
#
# Thu Sep 16 13:45:44 2021
# Total run time : 0 hours 0 minutes and 0 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -102.9797
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       102.98  |proj g|=       1.4179
# At iterate     1  f =       102.22  |proj g|=       0.57672
# At iterate     2  f =       101.61  |proj g|=       0.41314
# At iterate     3  f =        101.5  |proj g|=        1.5073
# At iterate     4  f =       101.45  |proj g|=        1.5005
# At iterate     5  f =        101.1  |proj g|=       0.59209
# At iterate     6  f =       101.07  |proj g|=       0.57727
# At iterate     7  f =       101.06  |proj g|=       0.16109
# At iterate     8  f =       101.05  |proj g|=       0.14779
# At iterate     9  f =       101.04  |proj g|=       0.38608
# At iterate    10  f =       101.03  |proj g|=       0.49683
# At iterate    11  f =       101.03  |proj g|=       0.36417
# At iterate    12  f =       101.03  |proj g|=      0.046412
# At iterate    13  f =       101.03  |proj g|=       0.00268
# At iterate    14  f =       101.03  |proj g|=    6.1253e-05
#
# iterations 14
# function evaluations 17
# segments explored during Cauchy searches 17
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 6.12532e-05
# final function value 101.025
#
# F = 101.025
# final  value 101.025036
# converged
#
#
# Thu Sep 16 13:45:44 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	5.209892e-03
#       1 	8.055561e-02
#       2 	2.161375e-01
#       3 	3.138414e-01
#       4 	3.138414e-01
#       5 	1.100441e+00
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 1.100441e+00
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	0.000000e+00	G[ 1] :	-1.412618e+01
#  X[ 2] :	5.950501e-01	G[ 2] :	-2.190411e-07
#  X[ 3] :	4.995841e-01	G[ 3] :	-6.431098e-09
#  X[ 4] :	1.000000e+00	G[ 4] :	5.261061e+00
#
# Solution Found Generation 5
# Number of Generations Run 8
#
# Thu Sep 16 13:45:44 2021
# Total run time : 0 hours 0 minutes and 0 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -108.8281
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       108.83  |proj g|=       1.6619
# At iterate     1  f =       105.96  |proj g|=       0.54765
# At iterate     2  f =       105.46  |proj g|=        0.5508
# At iterate     3  f =       105.12  |proj g|=        1.5356
# At iterate     4  f =       104.92  |proj g|=       0.43809
# At iterate     5  f =       104.52  |proj g|=        1.3791
# At iterate     6  f =       104.24  |proj g|=        1.4987
# At iterate     7  f =       104.19  |proj g|=       0.29874
# At iterate     8  f =       104.18  |proj g|=       0.37234
# At iterate     9  f =       104.13  |proj g|=       0.99947
# At iterate    10  f =       104.07  |proj g|=        1.3523
# At iterate    11  f =       104.05  |proj g|=       0.36848
# At iterate    12  f =       104.04  |proj g|=       0.61918
# At iterate    13  f =       104.04  |proj g|=     0.0074742
# At iterate    14  f =       104.04  |proj g|=    0.00045819
# At iterate    15  f =       104.04  |proj g|=    9.1809e-07
#
# iterations 15
# function evaluations 18
# segments explored during Cauchy searches 18
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 9.18092e-07
# final function value 104.043
#
# F = 104.043
# final  value 104.043184
# converged
#
#
# Thu Sep 16 13:45:44 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	2.324951e-02
#       1 	1.116888e-01
#       2 	1.601714e-01
#       3 	7.803314e-01
#       4 	7.803314e-01
#       5 	7.803314e-01
#       6 	7.803314e-01
#       7 	7.803314e-01
#       8 	7.803314e-01
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 7.803314e-01
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	0.000000e+00	G[ 1] :	-2.151346e+01
#  X[ 2] :	6.011609e-01	G[ 2] :	-5.690902e-07
#  X[ 3] :	2.244724e-01	G[ 3] :	-1.809463e-06
#  X[ 4] :	1.000000e+00	G[ 4] :	9.691044e+00
#
# Solution Found Generation 8
# Number of Generations Run 11
#
# Thu Sep 16 13:45:45 2021
# Total run time : 0 hours 0 minutes and 1 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -112.3058
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       112.31  |proj g|=       1.4266
# At iterate     1  f =       110.44  |proj g|=        1.0115
# At iterate     2  f =       107.66  |proj g|=       0.91712
# At iterate     3  f =       107.27  |proj g|=        1.5354
# At iterate     4  f =       106.45  |proj g|=        1.5332
# At iterate     5  f =       105.82  |proj g|=       0.56301
# At iterate     6  f =       105.64  |proj g|=        1.4941
# At iterate     7  f =       105.42  |proj g|=        1.2219
# At iterate     8  f =       105.39  |proj g|=       0.53888
# At iterate     9  f =       105.39  |proj g|=      0.061868
# At iterate    10  f =       105.39  |proj g|=      0.012096
# At iterate    11  f =       105.39  |proj g|=     0.0019495
# At iterate    12  f =       105.39  |proj g|=    3.8335e-07
#
# iterations 12
# function evaluations 16
# segments explored during Cauchy searches 15
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 3.83349e-07
# final function value 105.385
#
# F = 105.385
# final  value 105.385063
# converged
#
#
# Thu Sep 16 13:45:45 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	7.763604e-02
#       1 	1.145418e-01
#       2 	1.595690e-01
#       3 	1.968412e-01
#       4 	1.968412e-01
#       5 	1.968412e-01
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 1.968412e-01
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	2.731519e-01	G[ 1] :	-2.227211e-07
#  X[ 2] :	7.907005e-01	G[ 2] :	6.653359e-07
#  X[ 3] :	1.000000e+00	G[ 3] :	3.085871e-01
#  X[ 4] :	1.000000e+00	G[ 4] :	1.821390e+00
#
# Solution Found Generation 5
# Number of Generations Run 8
#
# Thu Sep 16 13:45:45 2021
# Total run time : 0 hours 0 minutes and 0 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -117.6666
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       117.67  |proj g|=       1.7013
# At iterate     1  f =       117.48  |proj g|=       0.89043
# At iterate     2  f =       114.09  |proj g|=       0.74902
# At iterate     3  f =       112.57  |proj g|=       0.72541
# At iterate     4  f =       110.14  |proj g|=        1.1984
# At iterate     5  f =        109.4  |proj g|=        1.5073
# At iterate     6  f =       109.19  |proj g|=       0.40402
# At iterate     7  f =        109.1  |proj g|=       0.57517
# At iterate     8  f =       108.97  |proj g|=       0.58913
# At iterate     9  f =       108.93  |proj g|=        1.4897
# At iterate    10  f =       108.91  |proj g|=        0.5856
# At iterate    11  f =       108.91  |proj g|=       0.21912
# At iterate    12  f =       108.91  |proj g|=      0.033661
# At iterate    13  f =       108.91  |proj g|=     0.0019654
# At iterate    14  f =       108.91  |proj g|=    3.3878e-05
#
# iterations 14
# function evaluations 18
# segments explored during Cauchy searches 19
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 3.38783e-05
# final function value 108.909
#
# F = 108.909
# final  value 108.908653
# converged
#
#
# Thu Sep 16 13:45:45 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	1.728467e-03
#       1 	4.158409e-02
#       2 	4.278605e-02
#       3 	7.408931e-01
#       4 	7.408931e-01
#       5 	7.408931e-01
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 7.408931e-01
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	0.000000e+00	G[ 1] :	-7.831845e+00
#  X[ 2] :	6.264344e-01	G[ 2] :	-2.608595e-06
#  X[ 3] :	1.000000e+00	G[ 3] :	1.685659e+00
#  X[ 4] :	1.000000e+00	G[ 4] :	4.473693e+00
#
# Solution Found Generation 5
# Number of Generations Run 8
#
# Thu Sep 16 13:45:45 2021
# Total run time : 0 hours 0 minutes and 0 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -114.9164
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       114.92  |proj g|=       1.5966
# At iterate     1  f =       113.51  |proj g|=       0.58466
# At iterate     2  f =       112.93  |proj g|=        1.3527
# At iterate     3  f =       111.98  |proj g|=       0.76023
# At iterate     4  f =       111.91  |proj g|=       0.43431
# At iterate     5  f =       111.81  |proj g|=        1.5006
# At iterate     6  f =       111.73  |proj g|=        1.4997
# At iterate     7  f =       111.65  |proj g|=       0.58445
# At iterate     8  f =       111.63  |proj g|=       0.32169
# At iterate     9  f =       111.63  |proj g|=      0.068139
# At iterate    10  f =       111.63  |proj g|=      0.012102
# At iterate    11  f =       111.63  |proj g|=    7.7365e-05
# At iterate    12  f =       111.63  |proj g|=    2.3366e-06
#
# iterations 12
# function evaluations 16
# segments explored during Cauchy searches 15
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 2.33659e-06
# final function value 111.631
#
# F = 111.631
# final  value 111.631061
# converged
#
#
# Thu Sep 16 13:45:46 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	7.734079e-04
#       1 	7.672295e-03
#       2 	2.128544e-02
#       3 	3.624703e-01
#       4 	3.624703e-01
#       5 	3.624703e-01
#       6 	3.624703e-01
#       7 	3.624703e-01
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 3.624703e-01
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	0.000000e+00	G[ 1] :	-1.253330e+01
#  X[ 2] :	5.472719e-01	G[ 2] :	1.629673e-08
#  X[ 3] :	0.000000e+00	G[ 3] :	-1.137968e-02
#  X[ 4] :	1.000000e+00	G[ 4] :	5.740759e+00
#
# Solution Found Generation 7
# Number of Generations Run 10
#
# Thu Sep 16 13:45:46 2021
# Total run time : 0 hours 0 minutes and 0 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -124.1765
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       124.18  |proj g|=       1.2419
# At iterate     1  f =       119.99  |proj g|=        1.0814
# At iterate     2  f =       116.63  |proj g|=        1.5825
# At iterate     3  f =       115.67  |proj g|=        1.1651
# At iterate     4  f =       115.17  |proj g|=        1.3893
# At iterate     5  f =       114.35  |proj g|=        1.5112
# At iterate     6  f =       114.16  |proj g|=        1.4935
# At iterate     7  f =        113.9  |proj g|=        0.4959
# At iterate     8  f =       113.78  |proj g|=       0.39334
# At iterate     9  f =        113.6  |proj g|=       0.55367
# At iterate    10  f =       113.56  |proj g|=        1.3635
# At iterate    11  f =       113.49  |proj g|=       0.40067
# At iterate    12  f =       113.48  |proj g|=       0.11864
# At iterate    13  f =       113.48  |proj g|=     0.0010402
# At iterate    14  f =       113.48  |proj g|=    9.3789e-06
#
# iterations 14
# function evaluations 18
# segments explored during Cauchy searches 18
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 9.37894e-06
# final function value 113.482
#
# F = 113.482
# final  value 113.481636
# converged
#
#
# Thu Sep 16 13:45:46 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	4.957596e-05
#       1 	2.166922e-04
#       2 	4.370016e-03
#       3 	5.717045e-02
#       4 	5.717045e-02
#       5 	5.717045e-02
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 5.717045e-02
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	4.845786e-01	G[ 1] :	-1.155863e-08
#  X[ 2] :	1.000000e+00	G[ 2] :	6.735363e-01
#  X[ 3] :	1.000000e+00	G[ 3] :	8.980094e-02
#  X[ 4] :	1.000000e+00	G[ 4] :	4.763666e-01
#
# Solution Found Generation 5
# Number of Generations Run 8
#
# Thu Sep 16 13:45:46 2021
# Total run time : 0 hours 0 minutes and 0 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -129.1136
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       129.11  |proj g|=       0.9355
# At iterate     1  f =       120.79  |proj g|=        1.5301
# At iterate     2  f =       119.53  |proj g|=       0.61127
# At iterate     3  f =       118.16  |proj g|=       0.55356
# At iterate     4  f =       117.71  |proj g|=        1.4851
# At iterate     5  f =       117.47  |proj g|=        1.4708
# At iterate     6  f =       117.43  |proj g|=       0.72967
# At iterate     7  f =        117.4  |proj g|=       0.38345
# At iterate     8  f =       117.34  |proj g|=         0.555
# At iterate     9  f =       117.25  |proj g|=       0.56781
# At iterate    10  f =       117.16  |proj g|=       0.57373
# At iterate    11  f =       117.14  |proj g|=        0.3973
# At iterate    12  f =       117.14  |proj g|=       0.01736
# At iterate    13  f =       117.14  |proj g|=     0.0016193
# At iterate    14  f =       117.14  |proj g|=    1.5532e-06
#
# iterations 14
# function evaluations 17
# segments explored during Cauchy searches 17
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 1.55319e-06
# final function value 117.139
#
# F = 117.139
# final  value 117.139067
# converged
#
#
# Thu Sep 16 13:45:46 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	7.167308e-06
#       1 	7.286714e-05
#       2 	4.153332e-04
#       3 	3.292935e-02
#       5 	3.292935e-02
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 3.292935e-02
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	0.000000e+00	G[ 1] :	-2.360006e+00
#  X[ 2] :	6.321652e-01	G[ 2] :	-4.873610e-08
#  X[ 3] :	5.239524e-01	G[ 3] :	7.930131e-08
#  X[ 4] :	1.000000e+00	G[ 4] :	2.171499e+00
#
# Solution Found Generation 5
# Number of Generations Run 8
#
# Thu Sep 16 13:45:47 2021
# Total run time : 0 hours 0 minutes and 1 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -129.952
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       129.95  |proj g|=       1.6661
# At iterate     1  f =       122.25  |proj g|=       0.64467
# At iterate     2  f =        121.3  |proj g|=       0.62266
# At iterate     3  f =       119.73  |proj g|=       0.55843
# At iterate     4  f =       119.21  |proj g|=        1.4749
# At iterate     5  f =       118.59  |proj g|=        1.4675
# At iterate     6  f =       118.35  |proj g|=        1.3637
# At iterate     7  f =       118.29  |proj g|=       0.39695
# At iterate     8  f =       118.28  |proj g|=       0.46135
# At iterate     9  f =       118.24  |proj g|=       0.56434
# At iterate    10  f =       118.18  |proj g|=       0.57857
# At iterate    11  f =       118.13  |proj g|=       0.56785
# At iterate    12  f =       118.12  |proj g|=       0.40442
# At iterate    13  f =       118.12  |proj g|=        0.3315
# At iterate    14  f =       118.12  |proj g|=     0.0029904
# At iterate    15  f =       118.12  |proj g|=    3.1647e-05
#
# iterations 15
# function evaluations 18
# segments explored during Cauchy searches 18
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 3.1647e-05
# final function value 118.118
#
# F = 118.118
# final  value 118.118014
# converged
#
#
# Thu Sep 16 13:45:47 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	5.631678e-05
#       1 	1.098941e-04
#       2 	6.433171e-04
#       3 	8.799208e-02
#       4 	8.799208e-02
#       5 	8.799208e-02
#
# 'wait.generations' limit reached.
# ...
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	2.964055e-05
#       1 	1.042287e-04
#       2 	5.555784e-04
#       3 	5.340802e-03
#       4 	5.340802e-03
#       5 	5.340802e-03
#       6 	5.340802e-03
#       7 	5.340802e-03
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 5.340802e-03
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	0.000000e+00	G[ 1] :	-3.526967e-01
#  X[ 2] :	4.777991e-01	G[ 2] :	-4.131796e-08
#  X[ 3] :	1.000000e+00	G[ 3] :	1.502234e-02
#  X[ 4] :	1.000000e+00	G[ 4] :	1.118935e-01
#
# Solution Found Generation 7
# Number of Generations Run 10
#
# Thu Sep 16 13:45:48 2021
# Total run time : 0 hours 0 minutes and 1 seconds
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -134.6482
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       134.65  |proj g|=       1.0457
# At iterate     1  f =       131.84  |proj g|=        1.4931
# At iterate     2  f =       128.91  |proj g|=        1.4827
# At iterate     3  f =       125.07  |proj g|=        1.4852
# At iterate     4  f =       124.55  |proj g|=        1.3646
# At iterate     5  f =       124.39  |proj g|=        1.3703
# At iterate     6  f =       124.27  |proj g|=        1.4613
# At iterate     7  f =       124.17  |proj g|=         1.464
# At iterate     8  f =       123.65  |proj g|=        1.4525
# At iterate     9  f =       123.57  |proj g|=       0.28804
# At iterate    10  f =       123.57  |proj g|=      0.038822
# At iterate    11  f =       123.57  |proj g|=     0.0059704
# At iterate    12  f =       123.57  |proj g|=    3.2702e-06
#
# iterations 12
# function evaluations 16
# segments explored during Cauchy searches 17
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 3.2702e-06
# final function value 123.567
#
# F = 123.567
# final  value 123.566782
# converged
#
#
# Thu Sep 16 13:45:48 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	1.105637e-05
#       1 	7.191734e-05
#       2 	1.621899e-04
#       3 	5.952798e-03
#       4 	5.952798e-03
#       5 	5.952798e-03
#       6 	5.952798e-03
#       7 	5.952798e-03
#       8 	5.952798e-03
#       9 	5.952798e-03
#      10 	5.952798e-03
#      11 	5.952798e-03
# Warning message in genoud(EI, nvars = d, max = TRUE, pop.size = control$pop.size, :
# “Stopped because hard maximum generation limit was hit.”
# plot without title
# NOTE: HARD MAXIMUM GENERATION LIMIT HIT
#
# Solution Fitness Value: 5.952798e-03
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	5.229348e-02	G[ 1] :	-1.560073e-07
#  X[ 2] :	6.205137e-01	G[ 2] :	-9.953543e-08
#  X[ 3] :	6.453704e-01	G[ 3] :	-6.232311e-08
#  X[ 4] :	1.000000e+00	G[ 4] :	4.217717e-01
#
# Solution Found Generation 11
# Number of Generations Run 12
#
# Thu Sep 16 13:45:48 2021
# Total run time : 0 hours 0 minutes and 0 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -141.6744
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       141.67  |proj g|=       1.6079
# At iterate     1  f =       137.86  |proj g|=       0.91475
# At iterate     2  f =       130.11  |proj g|=       0.89865
# At iterate     3  f =       129.12  |proj g|=        1.5318
# At iterate     4  f =       126.64  |proj g|=        1.4187
# At iterate     5  f =       125.74  |proj g|=        1.3541
# At iterate     6  f =       125.62  |proj g|=       0.79822
# At iterate     7  f =       125.38  |proj g|=       0.58844
# At iterate     8  f =       125.15  |proj g|=       0.61484
# At iterate     9  f =       124.96  |proj g|=       0.63731
# At iterate    10  f =       124.96  |proj g|=       0.55558
# At iterate    11  f =       124.96  |proj g|=      0.012779
# At iterate    12  f =       124.96  |proj g|=    0.00016122
# At iterate    13  f =       124.96  |proj g|=    3.3268e-07
#
# iterations 13
# function evaluations 18
# segments explored during Cauchy searches 16
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 3.32677e-07
# final function value 124.955
#
# F = 124.955
# final  value 124.955105
# converged
#
#
# Thu Sep 16 13:45:48 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	8.561275e-05
#       1 	2.517897e-03
#       2 	6.714301e-03
#       3 	2.393142e-02
#       5 	2.393142e-02
#       6 	2.393142e-02
#       7 	2.393142e-02
#
# 'wait.generations' limit reached.
# No significant improvement in 2 generations.
#
# Solution Fitness Value: 2.393142e-02
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	4.597467e-01	G[ 1] :	2.924006e-10
#  X[ 2] :	1.000000e+00	G[ 2] :	7.692315e-01
#  X[ 3] :	0.000000e+00	G[ 3] :	-1.188163e-01
#  X[ 4] :	1.000000e+00	G[ 4] :	2.512954e-01
#
# Solution Found Generation 7
# Number of Generations Run 10
#
# Thu Sep 16 13:45:49 2021
# Total run time : 0 hours 0 minutes and 1 seconds
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -151.1742
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       151.17  |proj g|=       1.6317
# At iterate     1  f =       139.49  |proj g|=        1.0128
# At iterate     2  f =       135.99  |proj g|=       0.83323
# At iterate     3  f =       131.54  |proj g|=       0.66573
# At iterate     4  f =          130  |proj g|=        1.3675
# At iterate     5  f =       129.05  |proj g|=         1.455
# At iterate     6  f =       128.29  |proj g|=       0.99689
# At iterate     7  f =        128.2  |proj g|=       0.41138
# At iterate     8  f =        128.2  |proj g|=      0.039043
# At iterate     9  f =        128.2  |proj g|=     0.0019752
# At iterate    10  f =        128.2  |proj g|=    0.00012138
#
# iterations 10
# function evaluations 13
# segments explored during Cauchy searches 13
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0.000121383
# final function value 128.198
#
# F = 128.198
# final  value 128.198313
# converged
#
#
# Thu Sep 16 13:45:49 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	5.105519e-08
#       1 	3.774267e-07
#       2 	1.592966e-06
#       3 	5.416654e-05
#       4 	5.416654e-05
#       5 	5.416654e-05
#       6 	5.416654e-05
#       7 	5.416654e-05
#       8 	5.416654e-05
#       9 	5.416654e-05
#      10 	5.416654e-05
#      11 	5.416654e-05
#      12 	5.416654e-05
# Warning message in genoud(EI, nvars = d, max = TRUE, pop.size = control$pop.size, :
# “Stopped because hard maximum generation limit was hit.”
# plot without title
# NOTE: HARD MAXIMUM GENERATION LIMIT HIT
#
# Solution Fitness Value: 5.416654e-05
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	6.542039e-01	G[ 1] :	2.813288e-09
#  X[ 2] :	1.000000e+00	G[ 2] :	1.692863e-03
#  X[ 3] :	1.000000e+00	G[ 3] :	4.135223e-04
#  X[ 4] :	0.000000e+00	G[ 4] :	-2.292337e-04
#
# Solution Found Generation 12
# Number of Generations Run 12
#
# Thu Sep 16 13:45:49 2021
# Total run time : 0 hours 0 minutes and 0 seconds
#
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -148.3306
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       148.33  |proj g|=       1.5048
# At iterate     1  f =       142.93  |proj g|=         1.042
# At iterate     2  f =       139.81  |proj g|=         1.489
# At iterate     3  f =       135.68  |proj g|=        1.5115
# At iterate     4  f =       132.48  |proj g|=       0.61294
# At iterate     5  f =       132.24  |proj g|=       0.58293
# At iterate     6  f =       132.18  |proj g|=        1.0063
# At iterate     7  f =       132.11  |proj g|=        1.3279
# At iterate     8  f =       131.98  |proj g|=        1.3211
# At iterate     9  f =       131.96  |proj g|=        1.2565
# At iterate    10  f =       131.96  |proj g|=      0.010129
# At iterate    11  f =       131.96  |proj g|=    0.00017002
#
# iterations 11
# function evaluations 14
# segments explored during Cauchy searches 14
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 0.000170019
# final function value 131.959
#
# F = 131.959
# final  value 131.959197
# converged
#
#
# Thu Sep 16 13:45:49 2021
# Domains:
#  0.000000e+00   <=  X1   <=    1.000000e+00
#  0.000000e+00   <=  X2   <=    1.000000e+00
#  0.000000e+00   <=  X3   <=    1.000000e+00
#  0.000000e+00   <=  X4   <=    1.000000e+00
#
# Data Type: Floating Point
# Operators (code number, name, population)
# 	(1) Cloning........................... 	5
# 	(2) Uniform Mutation.................. 	6
# 	(3) Boundary Mutation................. 	6
# 	(4) Non-Uniform Mutation.............. 	6
# 	(5) Polytope Crossover................ 	6
# 	(6) Simple Crossover.................. 	6
# 	(7) Whole Non-Uniform Mutation........ 	6
# 	(8) Heuristic Crossover............... 	6
# 	(9) Local-Minimum Crossover........... 	0
#
# HARD Maximum Number of Generations: 12
# Maximum Nonchanging Generations: 2
# Population size       : 48
# Convergence Tolerance: 1.000000e-21
#
# Using the BFGS Derivative Based Optimizer on the Best Individual Each Generation.
# Not Checking Gradients before Stopping.
# Not Using Out of Bounds Individuals and Not Allowing Trespassing.
#
# Maximization Problem.
#
#
# Generation#	    Solution Value
#
#       0 	1.732924e-07
#       1 	6.738590e-05
#       2 	7.695737e-04
#       3 	1.548313e-03
#       4 	1.548313e-03
#       5 	1.548313e-03
#       6 	1.548313e-03
#       7 	1.548313e-03
#       8 	1.548313e-03
#       9 	1.548313e-03
#      10 	1.548313e-03
#      11 	1.548313e-03
#      12 	1.548313e-03
# Warning message in genoud(EI, nvars = d, max = TRUE, pop.size = control$pop.size, :
# “Stopped because hard maximum generation limit was hit.”
# plot without title
# NOTE: HARD MAXIMUM GENERATION LIMIT HIT
#
# Solution Fitness Value: 1.548313e-03
#
# Parameters at the Solution (parameter, gradient):
#
#  X[ 1] :	2.463692e-01	G[ 1] :	3.201178e-08
#  X[ 2] :	7.506584e-01	G[ 2] :	-6.810951e-08
#  X[ 3] :	3.890712e-01	G[ 3] :	-7.901234e-08
#  X[ 4] :	1.000000e+00	G[ 4] :	8.136546e-02
#
# Solution Found Generation 12
# Number of Generations Run 12
#
# Thu Sep 16 13:45:50 2021
# Total run time : 0 hours 0 minutes and 1 seconds
# plot without title
# optimisation start
# ------------------
# * estimation method   : MLE
# * optimisation method : BFGS
# * analytical gradient : used
# * trend model : ~1
# * covariance model :
#   - type :  matern5_2
#   - nugget : NO
#   - parameters lower bounds :  1e-10 1e-10 1e-10 1e-10
#   - parameters upper bounds :  1.875968 1.83734 1.933866 1.914905
#   - best initial criterion value(s) :  -141.6444
#
# N = 4, M = 5 machine precision = 2.22045e-16
# At X0, 0 variables are exactly at the bounds
# At iterate     0  f=       141.64  |proj g|=      0.91395
# At iterate     1  f =       140.42  |proj g|=       0.85953
# At iterate     2  f =       137.82  |proj g|=        1.4871
# At iterate     3  f =       136.42  |proj g|=        1.4712
# At iterate     4  f =       134.57  |proj g|=       0.71185
# At iterate     5  f =        134.5  |proj g|=       0.58738
# At iterate     6  f =       134.36  |proj g|=        1.4508
# At iterate     7  f =        134.2  |proj g|=        1.4538
# At iterate     8  f =       134.06  |proj g|=        1.4396
# At iterate     9  f =       134.04  |proj g|=       0.35477
# At iterate    10  f =       134.04  |proj g|=      0.086996
# At iterate    11  f =       134.04  |proj g|=      0.043427
# At iterate    12  f =       134.04  |proj g|=      0.003245
# At iterate    13  f =       134.04  |proj g|=    3.7051e-05
#
# iterations 13
# function evaluations 15
# segments explored during Cauchy searches 16
# BFGS updates skipped 0
# active bounds at final generalized Cauchy point 2
# norm of the final projected gradient 3.70507e-05
# final function value 134.035
#
# F = 134.035
# final  value 134.035396
# converged
# longest shot observed: 186.04
# corresponding input values: 0 0.6 0 1
# plot without title

# %% [markdown]
# Global minimum found by EGO:

# %%
EGOpar[bestIndex, ]
runExperimentFun(EGOpar[bestIndex, ])
# Out:
# [1] 0.0000000 0.5951509 0.0000000 1.0000000
# [1] -186.0374
# plot without title

# %% [markdown]
# Let us visualize the 20 points computed with EGO in the X-Y space, and in time order.

# %%
visualizeEGO <- function(initDesign, initValues, EGOpoints, EGOvalues){
  bestIndex <- which.min(EGOvalues)
  y <- c(initValues, EGOvalues, EGOvalues[bestIndex])
  X <- rbind(initDesign, EGOpoints, EGOpoints[bestIndex, ])
  nsteps <- nrow(EGOpoints)
  pairs(cbind(y, X), 
        col = c(rep("black", ninit), rep("blue", nsteps), "red"),
        pch = c(rep(1, ninit), rep(19, nsteps + 1)))
}

visualizeEGO(initDesign = X, initValues = Y,
             EGOpoints = EGOpar, EGOvalues = EGOvalue)
# Out:
# plot without title

# %%
plot(c(Y, EGOvalue), main = "convergence", xlab = "evaluation number", ylab = "Y values")
lines(rep(ninit, 2), range(Y, EGOvalue), lty = 2, col = "gray")
lines(ninit + 0:nsteps, cummin(c(min(Y), EGOvalue)), col = "red", lwd = 2)
# Out:
# Plot with title “convergence”

# %% [markdown]
#  Questions :
#  * *Why the EGO method would be much less efficient by using a linear model instead of a GP model?*
#  * *Modify the code in order to deal with noisy observations, with the EQI criterion (mind using the argument 'noise.var' in 'km').*
#  * *Investigate the influence: [a] of a trend in the model (change 'formula' in 'km'); [b] of a kernel; [c] of the initial sample size.*
#  * *Adapt the EGO method in order to provide a batch of 2 points at one (function qEGO.nsteps), which is useful in practice, as the 2 runs of the time-consuming simulator can be done in parallel.*

# %% [markdown]
# Bonus : As the function is quick to evaluate, compare the result with the maximum value obtained with a standard optimizor (from library nloptr for instance). You can use the 'runExperimentFun' function defined above.
