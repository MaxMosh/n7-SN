# %%
from ultralytics import YOLO
import cv2
import math 
# start webcam
cap = cv2.VideoCapture(0)
cap.set(3, 640)
cap.set(4, 480)

# model
model = YOLO("yolov8n_100e.pt")

# object classes
classNames = ["visage"
              ]


while True:
    success, img = cap.read()
    #img = cv2.imread(image_path)
    results = model(img, stream=True)

    # coordinates
    for r in results:
        boxes = r.boxes

        for box in boxes:
            # bounding box
            x1, y1, x2, y2 = box.xyxy[0]
            x1, y1, x2, y2 = int(x1), int(y1), int(x2), int(y2) # convert to int values

            # put box in cam
            cv2.rectangle(img, (x1, y1), (x2, y2), (255, 0, 255), 3)

            # confidence
            confidence = math.ceil((box.conf[0]*100))/100
            print("Confidence --->",confidence)

            # class name
            cls = int(box.cls[0])
            print("Class name -->", classNames[cls])

            # object details
            org = [x1, y1]
            font = cv2.FONT_HERSHEY_SIMPLEX
            fontScale = 1
            color = (255, 0, 0)
            thickness = 2

            cv2.putText(img, classNames[cls], org, font, fontScale, color, thickness)

    cv2.imshow('Webcam', img)
    if cv2.waitKey(1) == ord('q'):
        break

cap.release()
cv2.destroyAllWindows()
# Out:
# 0: 480x640 4 Faces, 151.0ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.53
# Class name --> visage
# Confidence ---> 0.35
# Class name --> visage
# Speed: 5.0ms preprocess, 151.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 148.6ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.54
# Class name --> visage
# Confidence ---> 0.28
# Class name --> visage
# Speed: 3.4ms preprocess, 148.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 139.8ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.54
# Class name --> visage
# Confidence ---> 0.33
# Class name --> visage
# Speed: 2.8ms preprocess, 139.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 142.9ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Confidence ---> 0.26
# Class name --> visage
# Speed: 3.2ms preprocess, 142.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 164.5ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.48
# Class name --> visage
# Confidence ---> 0.36
# Class name --> visage
# Speed: 3.4ms preprocess, 164.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 152.0ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.33
# Class name --> visage
# Speed: 2.5ms preprocess, 152.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 157.9ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.37
# Class name --> visage
# Speed: 2.9ms preprocess, 157.9ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 137.8ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.31
# Class name --> visage
# Speed: 3.7ms preprocess, 137.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 171.2ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.45
# Class name --> visage
# Speed: 2.5ms preprocess, 171.2ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 160.1ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.46
# Class name --> visage
# Speed: 3.6ms preprocess, 160.1ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 151.6ms
# Confidence ---> 0.59
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.47
# Class name --> visage
# Speed: 3.3ms preprocess, 151.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 143.2ms
# Confidence ---> 0.59
# Class name --> visage
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.49
# Class name --> visage
# Speed: 3.5ms preprocess, 143.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 141.0ms
# Confidence ---> 0.59
# Class name --> visage
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.51
# Class name --> visage
# Speed: 2.5ms preprocess, 141.0ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 142.8ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Speed: 2.9ms preprocess, 142.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 154.6ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Speed: 3.0ms preprocess, 154.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 141.6ms
# Confidence ---> 0.59
# Class name --> visage
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Speed: 3.0ms preprocess, 141.6ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 149.9ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.53
# Class name --> visage
# Speed: 2.7ms preprocess, 149.9ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 141.3ms
# Confidence ---> 0.59
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.53
# Class name --> visage
# Speed: 2.8ms preprocess, 141.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 142.5ms
# Confidence ---> 0.6
# Class name --> visage
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.53
# Class name --> visage
# Speed: 2.8ms preprocess, 142.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 149.2ms
# Confidence ---> 0.6
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Speed: 2.3ms preprocess, 149.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 162.9ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.5
# Class name --> visage
# Speed: 2.8ms preprocess, 162.9ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 144.9ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.5
# Class name --> visage
# Speed: 2.9ms preprocess, 144.9ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 145.6ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.5
# Class name --> visage
# Speed: 4.0ms preprocess, 145.6ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 142.8ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.51
# Class name --> visage
# Speed: 3.3ms preprocess, 142.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 158.3ms
# Confidence ---> 0.6
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.51
# Class name --> visage
# Speed: 2.6ms preprocess, 158.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 152.4ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Speed: 3.7ms preprocess, 152.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 152.6ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.51
# Class name --> visage
# Speed: 3.3ms preprocess, 152.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 155.0ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.54
# Class name --> visage
# Confidence ---> 0.48
# Class name --> visage
# Speed: 3.2ms preprocess, 155.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 142.5ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Speed: 3.7ms preprocess, 142.5ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 175.7ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Speed: 5.1ms preprocess, 175.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 157.7ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.54
# Class name --> visage
# Speed: 2.6ms preprocess, 157.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 148.4ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Speed: 2.9ms preprocess, 148.4ms inference, 2.0ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 159.8ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Speed: 3.1ms preprocess, 159.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 155.4ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.54
# Class name --> visage
# Confidence ---> 0.27
# Class name --> visage
# Confidence ---> 0.27
# Class name --> visage
# Speed: 2.7ms preprocess, 155.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 146.3ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Speed: 2.9ms preprocess, 146.3ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 151.8ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 3.1ms preprocess, 151.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 142.7ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.49
# Class name --> visage
# Confidence ---> 0.45
# Class name --> visage
# Speed: 2.8ms preprocess, 142.7ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 145.7ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.49
# Class name --> visage
# Confidence ---> 0.48
# Class name --> visage
# Speed: 4.2ms preprocess, 145.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 157.5ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.46
# Class name --> visage
# Confidence ---> 0.44
# Class name --> visage
# Speed: 3.2ms preprocess, 157.5ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 150.8ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.44
# Class name --> visage
# Confidence ---> 0.42
# Class name --> visage
# Speed: 2.5ms preprocess, 150.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 148.7ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.46
# Class name --> visage
# Speed: 3.0ms preprocess, 148.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 146.3ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Speed: 2.7ms preprocess, 146.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 152.0ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Speed: 3.9ms preprocess, 152.0ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 145.7ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.5
# Class name --> visage
# Confidence ---> 0.3
# Class name --> visage
# Speed: 4.6ms preprocess, 145.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 153.3ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.42
# Class name --> visage
# Confidence ---> 0.37
# Class name --> visage
# Confidence ---> 0.32
# Class name --> visage
# Speed: 3.0ms preprocess, 153.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 154.4ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.44
# Class name --> visage
# Confidence ---> 0.43
# Class name --> visage
# Confidence ---> 0.35
# Class name --> visage
# Speed: 3.5ms preprocess, 154.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 142.1ms
# Confidence ---> 0.59
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Confidence ---> 0.39
# Class name --> visage
# Speed: 2.8ms preprocess, 142.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 158.6ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.53
# Class name --> visage
# Confidence ---> 0.37
# Class name --> visage
# Speed: 5.2ms preprocess, 158.6ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 149.8ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.51
# Class name --> visage
# Confidence ---> 0.37
# Class name --> visage
# Speed: 2.3ms preprocess, 149.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 2 Faces, 88.6ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 3.0ms preprocess, 88.6ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 92.9ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.34
# Class name --> visage
# Confidence ---> 0.3
# Class name --> visage
# Speed: 1.4ms preprocess, 92.9ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 101.8ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.54
# Class name --> visage
# Confidence ---> 0.3
# Class name --> visage
# Confidence ---> 0.26
# Class name --> visage
# Speed: 1.4ms preprocess, 101.8ms inference, 0.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 91.8ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.37
# Class name --> visage
# Speed: 1.5ms preprocess, 91.8ms inference, 0.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 139.9ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.43
# Class name --> visage
# Confidence ---> 0.33
# Class name --> visage
# Confidence ---> 0.3
# Class name --> visage
# Speed: 2.6ms preprocess, 139.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 139.3ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.42
# Class name --> visage
# Confidence ---> 0.3
# Class name --> visage
# Confidence ---> 0.28
# Class name --> visage
# Speed: 3.0ms preprocess, 139.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 154.8ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.44
# Class name --> visage
# Confidence ---> 0.33
# Class name --> visage
# Confidence ---> 0.31
# Class name --> visage
# Speed: 3.2ms preprocess, 154.8ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 144.5ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.43
# Class name --> visage
# Confidence ---> 0.32
# Class name --> visage
# Confidence ---> 0.29
# Class name --> visage
# Speed: 3.2ms preprocess, 144.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 178.0ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.4
# Class name --> visage
# Confidence ---> 0.27
# Class name --> visage
# Speed: 4.5ms preprocess, 178.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 139.7ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.43
# Class name --> visage
# Confidence ---> 0.26
# Class name --> visage
# Speed: 2.4ms preprocess, 139.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 140.0ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.39
# Class name --> visage
# Confidence ---> 0.38
# Class name --> visage
# Speed: 3.2ms preprocess, 140.0ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 145.7ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.33
# Class name --> visage
# Speed: 3.3ms preprocess, 145.7ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 149.5ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.36
# Class name --> visage
# Confidence ---> 0.27
# Class name --> visage
# Confidence ---> 0.26
# Class name --> visage
# Speed: 3.4ms preprocess, 149.5ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 6 Faces, 156.4ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.36
# Class name --> visage
# Confidence ---> 0.35
# Class name --> visage
# Confidence ---> 0.3
# Class name --> visage
# Confidence ---> 0.29
# Class name --> visage
# Speed: 3.3ms preprocess, 156.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 158.7ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.37
# Class name --> visage
# Speed: 3.2ms preprocess, 158.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 139.8ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.44
# Class name --> visage
# Confidence ---> 0.3
# Class name --> visage
# Confidence ---> 0.29
# Class name --> visage
# Speed: 5.0ms preprocess, 139.8ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 91.9ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.46
# Class name --> visage
# Confidence ---> 0.36
# Class name --> visage
# Confidence ---> 0.35
# Class name --> visage
# Speed: 1.8ms preprocess, 91.9ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 112.1ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.48
# Class name --> visage
# Confidence ---> 0.39
# Class name --> visage
# Confidence ---> 0.38
# Class name --> visage
# Speed: 1.7ms preprocess, 112.1ms inference, 0.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 91.1ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.48
# Class name --> visage
# Confidence ---> 0.38
# Class name --> visage
# Speed: 1.5ms preprocess, 91.1ms inference, 0.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 120.5ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.46
# Class name --> visage
# Confidence ---> 0.39
# Class name --> visage
# Confidence ---> 0.37
# Class name --> visage
# Speed: 1.6ms preprocess, 120.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 157.5ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.47
# Class name --> visage
# Confidence ---> 0.39
# Class name --> visage
# Confidence ---> 0.37
# Class name --> visage
# Speed: 3.1ms preprocess, 157.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 168.6ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.47
# Class name --> visage
# Confidence ---> 0.39
# Class name --> visage
# Confidence ---> 0.37
# Class name --> visage
# Speed: 2.8ms preprocess, 168.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 143.3ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.5
# Class name --> visage
# Confidence ---> 0.36
# Class name --> visage
# Speed: 3.3ms preprocess, 143.3ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 138.9ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.33
# Class name --> visage
# Speed: 2.8ms preprocess, 138.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 137.5ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Speed: 2.6ms preprocess, 137.5ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 147.7ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 3.6ms preprocess, 147.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 137.6ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Speed: 3.4ms preprocess, 137.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 148.8ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 3.4ms preprocess, 148.8ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 151.6ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 2.8ms preprocess, 151.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 144.6ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Speed: 3.4ms preprocess, 144.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 153.7ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.54
# Class name --> visage
# Speed: 2.6ms preprocess, 153.7ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 153.0ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Speed: 2.6ms preprocess, 153.0ms inference, 2.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 140.5ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 4.3ms preprocess, 140.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 140.1ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 4.3ms preprocess, 140.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 179.5ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 3.4ms preprocess, 179.5ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 155.4ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Speed: 5.3ms preprocess, 155.4ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 147.3ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.48
# Class name --> visage
# Speed: 4.2ms preprocess, 147.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 157.8ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.29
# Class name --> visage
# Speed: 4.2ms preprocess, 157.8ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 151.2ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.48
# Class name --> visage
# Speed: 4.2ms preprocess, 151.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 157.7ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.47
# Class name --> visage
# Speed: 2.4ms preprocess, 157.7ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 160.1ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.28
# Class name --> visage
# Speed: 2.9ms preprocess, 160.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 156.9ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 3.7ms preprocess, 156.9ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 152.2ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.27
# Class name --> visage
# Speed: 2.8ms preprocess, 152.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 142.2ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.26
# Class name --> visage
# Speed: 3.2ms preprocess, 142.2ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 140.3ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 2.6ms preprocess, 140.3ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 150.4ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 4.7ms preprocess, 150.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 153.7ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 2.6ms preprocess, 153.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 133.1ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 3.0ms preprocess, 133.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 154.4ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 3.4ms preprocess, 154.4ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 152.6ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 2.9ms preprocess, 152.6ms inference, 2.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 160.3ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 3.1ms preprocess, 160.3ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 145.4ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 3.0ms preprocess, 145.4ms inference, 1.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 150.3ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 2.9ms preprocess, 150.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 145.4ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 2.9ms preprocess, 145.4ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 157.3ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.54
# Class name --> visage
# Speed: 3.0ms preprocess, 157.3ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 147.4ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.48
# Class name --> visage
# Speed: 3.3ms preprocess, 147.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 143.1ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Speed: 3.3ms preprocess, 143.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 145.3ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Speed: 3.8ms preprocess, 145.3ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 148.8ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.53
# Class name --> visage
# Speed: 2.9ms preprocess, 148.8ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 147.1ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.49
# Class name --> visage
# Speed: 2.6ms preprocess, 147.1ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 143.5ms
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.4
# Class name --> visage
# Speed: 2.8ms preprocess, 143.5ms inference, 1.7ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 132.6ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.4
# Class name --> visage
# Speed: 2.5ms preprocess, 132.6ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 151.1ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.43
# Class name --> visage
# Speed: 4.0ms preprocess, 151.1ms inference, 2.8ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 170.2ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.45
# Class name --> visage
# Speed: 3.2ms preprocess, 170.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 143.9ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.36
# Class name --> visage
# Speed: 3.0ms preprocess, 143.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 143.6ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.48
# Class name --> visage
# Speed: 3.1ms preprocess, 143.6ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 138.1ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.46
# Class name --> visage
# Speed: 3.4ms preprocess, 138.1ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 149.0ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.51
# Class name --> visage
# Confidence ---> 0.51
# Class name --> visage
# Speed: 2.9ms preprocess, 149.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 144.5ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.51
# Class name --> visage
# Confidence ---> 0.51
# Class name --> visage
# Speed: 2.9ms preprocess, 144.5ms inference, 1.9ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 142.1ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.48
# Class name --> visage
# Confidence ---> 0.45
# Class name --> visage
# Confidence ---> 0.34
# Class name --> visage
# Speed: 2.8ms preprocess, 142.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 160.5ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.5
# Class name --> visage
# Confidence ---> 0.48
# Class name --> visage
# Speed: 3.0ms preprocess, 160.5ms inference, 2.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 144.2ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.53
# Class name --> visage
# Confidence ---> 0.51
# Class name --> visage
# Speed: 2.4ms preprocess, 144.2ms inference, 2.1ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 145.0ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.54
# Class name --> visage
# Confidence ---> 0.49
# Class name --> visage
# Speed: 3.7ms preprocess, 145.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 148.7ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.5
# Class name --> visage
# Speed: 2.8ms preprocess, 148.7ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 159.1ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.44
# Class name --> visage
# Speed: 3.1ms preprocess, 159.1ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 139.4ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.45
# Class name --> visage
# Speed: 3.0ms preprocess, 139.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 145.4ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.42
# Class name --> visage
# Speed: 4.1ms preprocess, 145.4ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 142.5ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.4
# Class name --> visage
# Speed: 3.3ms preprocess, 142.5ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 141.9ms
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.35
# Class name --> visage
# Speed: 2.5ms preprocess, 141.9ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 136.0ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.29
# Class name --> visage
# Speed: 3.3ms preprocess, 136.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 144.4ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.27
# Class name --> visage
# Speed: 3.0ms preprocess, 144.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 133.0ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.29
# Class name --> visage
# Speed: 3.9ms preprocess, 133.0ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 132.2ms
# Confidence ---> 0.55
# Class name --> visage
# Confidence ---> 0.54
# Class name --> visage
# Confidence ---> 0.28
# Class name --> visage
# Speed: 2.6ms preprocess, 132.2ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 133.4ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.54
# Class name --> visage
# Speed: 2.5ms preprocess, 133.4ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 134.1ms
# Confidence ---> 0.59
# Class name --> visage
# Confidence ---> 0.58
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 2.6ms preprocess, 134.1ms inference, 1.2ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 128.1ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 2.4ms preprocess, 128.1ms inference, 1.6ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 150.4ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Speed: 3.1ms preprocess, 150.4ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 158.7ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.53
# Class name --> visage
# Speed: 2.9ms preprocess, 158.7ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 5 Faces, 140.0ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.53
# Class name --> visage
# Confidence ---> 0.48
# Class name --> visage
# Confidence ---> 0.4
# Class name --> visage
# Confidence ---> 0.29
# Class name --> visage
# Speed: 2.9ms preprocess, 140.0ms inference, 1.3ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 144.4ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Confidence ---> 0.49
# Class name --> visage
# Confidence ---> 0.4
# Class name --> visage
# Speed: 2.7ms preprocess, 144.4ms inference, 1.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 134.0ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.49
# Class name --> visage
# Confidence ---> 0.47
# Class name --> visage
# Confidence ---> 0.46
# Class name --> visage
# Speed: 2.6ms preprocess, 134.0ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 3 Faces, 168.6ms
# Confidence ---> 0.57
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Confidence ---> 0.45
# Class name --> visage
# Speed: 5.0ms preprocess, 168.6ms inference, 2.4ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 159.2ms
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.54
# Class name --> visage
# Confidence ---> 0.52
# Class name --> visage
# Confidence ---> 0.44
# Class name --> visage
# Speed: 3.1ms preprocess, 159.2ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
#
# 0: 480x640 4 Faces, 149.3ms
# Confidence ---> 0.59
# Class name --> visage
# Confidence ---> 0.56
# Class name --> visage
# Confidence ---> 0.54
# Class name --> visage
# Confidence ---> 0.43
# Class name --> visage
# Speed: 2.9ms preprocess, 149.3ms inference, 1.5ms postprocess per image at shape (1, 3, 480, 640)
