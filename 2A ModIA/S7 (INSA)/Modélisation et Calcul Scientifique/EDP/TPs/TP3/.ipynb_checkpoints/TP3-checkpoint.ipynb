# %% [markdown]
# # __<div align="center">EDP : TP3 - Monotonie et limiteurs</div>__

# %%
import matplotlib.pyplot as plt
import numpy as np

# %% [markdown]
# ## **0. Implémentation**

# %% [markdown]
# ### **0.1. Implémentations des limiteurs**

# %%
def sans_lim(r):
    return 1

def lim_minmod(r):
    if r >= 0 :
        eval_min = min(r,1)
    else :
        eval_min = 0
    return eval_min

def lim_superbee(r):
    return max(0, min(2*r, 1), min(r,2))

def lim_vanleer(r):
    # On traite le cas où 1 + r = 0
    if r == - 1 :
        ret = (r + abs(r))/(1 + r + 1e-9)
    else :
        ret = (r + abs(r))/(1 + r)
    return ret

def lim_vanalbada(r):
    return (r**2 + r)/(r**2 + 1)

# %% [markdown]
# ### **0.2. Implémentations des schémas limités**

# %% [markdown]
# #### __0.2.1. BW limité__

# %%
def BW_u_i_nplus1(u_iplus1_n, u_i_n, u_imoins1_n, u_imoins2_n, C, limiteur):
    if ((u_i_n - u_imoins1_n) == 0) :
        den_ri = 1e-9
    else :
        den_ri = u_i_n - u_imoins1_n
    if ((u_imoins1_n - u_imoins2_n) == 0) :
        den_rimoins1 = 1e-9
    else :
        den_rimoins1 = u_imoins1_n - u_imoins2_n
    r_i = (u_iplus1_n - u_i_n)/den_ri
    r_imoins1 = (u_i_n - u_imoins1_n)/den_rimoins1
    return u_i_n - C * (u_i_n - u_imoins1_n) - (C/2) * (1 - C) * limiteur(r_i) * (u_i_n - u_imoins1_n) + (C/2) * (1 - C) * limiteur(r_imoins1) * (u_imoins1_n - u_imoins2_n)

# %% [markdown]
# #### __0.2.2. LW limité__

# %%
def LW_u_i_nplus1(u_iplus1_n, u_i_n, u_imoins1_n, u_imoins2_n, C, limiteur): # TODO : à finir
    if ((u_iplus1_n - u_i_n) == 0) :
        den_Ri = 1e-9
    else :
        den_Ri = u_iplus1_n - u_i_n
    if ((u_i_n - u_imoins1_n) == 0) :
        den_Rimoins1 = 1e-9
    else :
        den_Rimoins1 = u_i_n - u_imoins1_n
    R_i = (u_i_n - u_imoins1_n)/den_Ri
    R_imoins1 = (u_imoins1_n - u_imoins2_n)/den_Rimoins1
    return u_i_n - C * (u_i_n - u_imoins1_n) - (C/2) * (1 - C) * limiteur(R_i) * (u_iplus1_n - u_i_n) + (C/2) * (1 - C) * limiteur(R_imoins1) * (u_i_n - u_imoins1_n)

# %% [markdown]
# **`Note sur le code :`** pour chaque coefficient $r_i$, on doit faire une vérification que le dénominateur ne soit pas nul.

# %% [markdown]
# ### **0.3. Implémentations autres**

# %%
# Constantes
C = 0.5

L = 1       # L = 1m
m = 50      # m = 50
x0 = 0.5    # x0 = 0.5m

a = 1       # a = 1m/s

T = 1
deltax = L/m
deltaT = C*deltax/a
p = int(T/deltaT)

abscisse = np.linspace(0,L,m)
abscisse_temps = np.linspace(0,T,p)


def CI(x,x0):
    return x > x0

u0 = np.vectorize(CI)(abscisse,x0)


""" Ancienne fonction TV : erreur quelque part
# Fonction TV
def TV(u_n):
    ret = 0
    for i in range(len(u_n)):
        ret += abs(u_n[(i+1)%len(u_n)] - u_n[i])
    return ret
"""

# Fonction TV évaluée pour plusieurs u_n (renvoie un vecteur contenant plusieurs scalaires)
def TV(une_grille):
    return np.sum(np.abs(une_grille - np.roll(une_grille,1)), 0)

def grille(m, p, u0, schema, C, limiteur) :
    grille_retour = np.zeros((m,p))
    grille_retour[:,0] = u0
    for n in range(1,p) :
        for i in range(m) :
            grille_retour[i,n] = schema(grille_retour[(i + 1)%m,n - 1], grille_retour[i,n - 1], grille_retour[i - 1,n - 1], grille_retour[i - 2,n - 1], C, limiteur)
    return grille_retour


liste_limiteurs = [sans_lim, lim_minmod, lim_superbee, lim_vanleer, lim_vanalbada]
liste_noms_limiteurs = ["sans limiteur", "avec limiteur Min-mod", "avec limiteur Superbee", "avec limiteur Van-Leer", "avec limiteur Van-Albada"]
liste_schemas = [BW_u_i_nplus1, LW_u_i_nplus1]
liste_noms_schemas = ["BW", "LW"]

# %% [markdown]
# ## **1. Traçage sans et avec limiteurs**

# %%
# TODO : retirer ce bloc python

grille_BW_sans_lim = grille(m, p, u0, BW_u_i_nplus1, C, lim_minmod)

plt.plot(abscisse, grille_BW_sans_lim[:,0])
plt.plot(abscisse, grille_BW_sans_lim[:,-1])

"""liste_TV = np.zeros(np.size(grille_BW_sans_lim,1))
for i in range(np.size(grille_BW_sans_lim,1)) :
    liste_TV[i] = TV(grille_BW_sans_lim[:][i])
"""
liste_TV = TV(grille_BW_sans_lim)
plt.plot(abscisse_temps, liste_TV)
plt.grid()

# %%
ind_schema = 0
for schema in liste_schemas :
    plt.figure(figsize=(20, 10))
    ind_lim = 0
    for limiteur in liste_limiteurs :
        plt.subplot(2,len(liste_limiteurs), ind_lim + 1)
        grille_temp = grille(m, p, u0, schema, C, limiteur)
        plt.plot(abscisse, grille_temp[:,0])
        plt.plot(abscisse, grille_temp[:,-1])
        plt.title(liste_noms_schemas[ind_schema] + ", " + liste_noms_limiteurs[ind_lim])
        plt.grid()
        """ TODO : à retirer (ancienne fonction)
        #liste_TV = np.zeros(np.size(grille_temp,1))
        liste_TV = []
        for i in range(np.size(grille_temp,0)) :
            liste_TV.append(TV(grille_temp[i][:]))
        """
        liste_TV = TV(grille_temp)
        # TODO : remplacer la ligne qui suit par quelque chose d'un point moins triche
        liste_TV[0] = 0
        plt.subplot(2,len(liste_limiteurs), ind_lim + 1 + len(liste_limiteurs))
        plt.plot(abscisse_temps,liste_TV)
        plt.grid()
        ind_lim += 1
    ind_schema += 1

# %% [markdown]
# TODO : commenter les résulats (dernière question normalement)

# %% [markdown]
# TODO : supprimer le code ci-dessous

# %%
def FOUEE_u_i_nplus1(rien, u_i_n, u_imoinsun_n, rien2, C) :
    return u_i_n - C*(u_i_n - u_imoinsun_n)

def UPO2VF_EE_u_i_nplus1(u_iplusun_n, u_i_n, u_imoinsun_n, u_imoinsdeux_n, C):
    return u_i_n - (C/4)*(u_iplusun_n + 3*u_i_n - 5*u_imoinsun_n + u_imoinsdeux_n)

# %% [markdown]
# #### __1.2. Tester le programme sur les CFLs 0.1, 0.5 et 1. Que peut-on observer avec les deux schémas ?__

# %%
C_liste = [0.1, 0.5, 1]

# %%
# Constantes

L = 1       # L = 1m
m = 50      # m = 50
x0 = 0.5    # x0 = 0.5m

a = 1       # a = 1m/s

T = 1
deltax = L/m

deltaT_liste = [C_liste[i]*deltax/a for i in range(len(C_liste))]
p_liste = [int(T/deltaT_liste[i]) for i in range(len(deltaT_liste))]

abscisse = np.linspace(0,L,m)


def CI(x,x0):
    return x > x0

u0 = np.vectorize(CI)(abscisse,x0)
