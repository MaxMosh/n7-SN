# %%
import torch

import random as rd
import numpy as np

# %%
print(torch.cuda.is_available())
# Out:
# True

# %%
d = 5
n = 100

theta = np.ones(d)
sigma = 3.0

# %%
def generate_data(d,n,theta,sigma):
    X = np.random.randn(d,n)
    Y = np.matmul(np.transpose(X),theta) + sigma*np.random.randn(n)
    return X,Y

generate_data(d,n,theta,sigma)
# Out:
# (array([[ 2.64733598e-02, -9.56955890e-01, -8.10433669e-01,
#           1.65992892e-02,  1.58366313e+00,  1.88520036e+00,
#           4.71631827e-01, -3.71834040e-02, -2.24246241e-01,
#          -4.90732765e-01,  1.06744698e+00, -6.69069834e-02,
#          -1.49350771e+00, -4.62085544e-01, -3.58237077e-01,
#          -2.01536024e-01,  9.75798095e-01,  2.33315351e+00,
#          -2.13574743e-02,  6.93374686e-01, -4.88180233e-01,
#          -5.50929691e-01,  1.40681879e+00,  5.18092310e-01,
#          -3.83273231e-01, -3.39326268e-01,  1.22356010e+00,
#           9.57084120e-01,  1.48562786e+00, -5.98524552e-01,
#          -1.21347628e+00,  6.13616026e-01,  1.14552844e+00,
#          -1.11241063e+00,  8.31586129e-01,  1.37708262e+00,
#          -5.40688897e-01, -1.65693387e+00,  2.12497261e-03,
#           1.29867398e-01,  4.42674582e-01,  2.97844348e-01,
#           6.34843957e-01,  1.68135905e+00,  1.21507445e-01,
#          -1.38312757e+00,  2.23990857e-01,  4.69542187e-01,
# ...

# %%
def E(w,theta,sigma):
    return 0.5*np.transpose(w - theta)*(w - theta) + (sigma**2)/2 # pour une matrice Espérance[X * transpos(X)] qui vaut I_n

E([1,1])

# %%
def En(w, X, Y):
    return (0.5/len(X)) * np.sum(np.dot((X,w) - Y)**2) # TODO : vérifier qu'on a pris le bon np.size (len)

# %%
def grad_En(w, X, Y):
    return (1/len(X)) * X * (np.transpose(X) * w - Y)

# %%
def grad_sto_En(w, X, Y, n_batch):
    ind_sto = np.random.randint(len(X), n_batch)
    X_sto = X[ind_sto]
    Y_sto = Y[ind_sto]
    return grad_En(w, X_sto, Y_sto)

# %%
def eval_lipsch_grad_En(un_grad_En):
    return (1/len(X)) * X * transpose(X) # TODO : à revoir ici
